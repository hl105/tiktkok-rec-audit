# %% [markdown]
# goal: clean our messy dataset <br>
# output: cleaned.csv

# %%
import csv
import pandas as pd
df_pyktok = pd.read_csv('./pyktok_output.csv')

# %%
def determine_category(info):
    if type(info) == str:
        if 'sports' in info.lower() or 'fitness' in info.lower() or 'outdoor' in info.lower():
            return 'sports'
        elif 'beauty' in info.lower() or 'style' in info.lower():
            return 'beauty'
        elif 'society' in info.lower() or 'news' in info.lower() or 'social issues' in info.lower():
            return 'society'
        else:
            return 'other'
    else:
        return None
    
#label category    
df_pyktok['category'] = df_pyktok['diversificationLabels'].apply(determine_category)

# %%
category_counts = df_pyktok['category'].value_counts(dropna=False)
category_counts
#since there are only  148 none values, we'll manually look thru and check the categories
#df_pyktok.to_csv('./df_pyktok.csv')
df_pyktok = pd.read_csv('./df_pyktok.csv')

# %%
category_counts
# Out:
# category
# other      1247
# beauty      408
# sports      199
# society     195
# None        148
# Name: count, dtype: int64

# %%
link_to_category_dict = pd.Series(df_pyktok['category'].values, index=df_pyktok['video_id']).to_dict()
link_to_likes_dict = pd.Series(df_pyktok['video_diggcount'].values, index=df_pyktok['video_id']).to_dict()
link_to_author_dict = pd.Series(df_pyktok['author_username'].values, index=df_pyktok['video_id']).to_dict()

# %%
import json

with open('./original_merged_data.json') as f:
    dct_scraped = json.load(f)

dct_scraped[0]
# Out:
# {'distributed_link': 'https://www.tiktok.com/@_giannalove/video/7325171122000055598',
#  'rec_links': {'beauty_rec_1': 'https://www.tiktok.com/@certified_hassan/video/7360247028833733893',
#   'beauty_rec_2': 'https://www.tiktok.com/@nsw.trainvlogs/video/7360242264662199568',
#   'beauty_rec_3': 'https://www.tiktok.com/@zachking/video/7338816875956030766',
#   'beauty_rec_4': 'https://www.tiktok.com/@user1013040614268/video/7360258895568211205',
#   'beauty_rec_5': 'https://www.tiktok.com/@riize_official/video/7360211842804796689',
#   'beauty_rec_6': 'https://www.tiktok.com/@sugaritumanisss/video/7360387186988043525',
#   'beauty_rec_7': 'https://www.tiktok.com/@_giannalove/video/7350718404279438634',
#   'beauty_rec_8': 'https://www.tiktok.com/@deboraseoane/video/7360487735368502533',
#   'sports_rec_1': 'https://www.tiktok.com/@wsgwitit20/video/7360386897736207624',
#   'sports_rec_2': 'https://www.tiktok.com/@_giannalove/video/7350718404279438634',
#   'sports_rec_3': 'https://www.tiktok.com/@itsyaboyaustin4/video/7358522452261080362',
#   'sports_rec_4': 'https://www.tiktok.com/@_giannalove/video/7340754557351382315',
#   'sports_rec_5': 'https://www.tiktok.com/@marvilla_2007/video/7360354218143747334',
#   'sports_rec_6': 'https://www.tiktok.com/@volleyball__worlddd/video/7353398649449172270',
#   'sports_rec_7': 'https://www.tiktok.com/@mhiz.gladys0/video/7360306784571018501',
#   'sports_rec_8': 'https://www.tiktok.com/@user3026964558013/video/7360363985666952453',
#   'society_rec_1': 'https://www.tiktok.com/@user6610103488453/video/7360260508760476933',
#   'society_rec_2': 'https://www.tiktok.com/@_giannalove/video/7340754557351382315',
#   'society_rec_3': 'https://www.tiktok.com/@useradejoke43/video/7359992420400090374',
#   'society_rec_4': 'https://www.tiktok.com/@ilassabelem07/video/7360295918442188037',
#   'society_rec_5': 'https://www.tiktok.com/@_giannalove/video/7350718404279438634',
#   'society_rec_6': 'https://www.tiktok.com/@dailywire/video/7338905690012028206',
#   'society_rec_7': 'https://www.tiktok.com/@fq2001/video/7360296841549712646',
#   'society_rec_8': 'https://www.tiktok.com/@_giannalove/video/7340721843600379178',
#   'control_society_rec_1': 'https://www.tiktok.com/@_giannalove/video/7350718404279438634',
#   'control_society_rec_2': 'https://www.tiktok.com/@_giannalove/video/7340754557351382315',
#   'control_society_rec_3': 'https://www.tiktok.com/@josiealesch/video/7349236600494116139',
#   'control_society_rec_4': 'https://www.tiktok.com/@_giannalove/video/7349624601309220138',
#   'control_society_rec_5': 'https://www.tiktok.com/@_giannalove/video/7342172600455449899',
#   'control_society_rec_6': 'https://www.tiktok.com/@_giannalove/video/7340721843600379178',
#   'control_society_rec_7': 'https://www.tiktok.com/@_giannalove/video/7355206355315100970',
#   'control_society_rec_8': 'https://www.tiktok.com/@marvilla_2007/video/7360354218143747334'}}

# %%
df_pyktok['category'].value_counts(dropna = False)
# Out:
# category
# other      1360
# beauty      413
# society     217
# sports      204
# NaN           3
# Name: count, dtype: int64

# %%
#main code block
#we rebuild the dataset with the categories
rows = []
for item in dct_scraped:
    dst_id = item['distributed_link'].split('/')[-1].split('?')[0]
    dstr_category = None
    dstr_author = None
    
    try: #check if we have pyktok data for video
        dstr_category = link_to_category_dict[int(dst_id)]
        dstr_author = link_to_author_dict[int(dst_id)]
    except:
        pass
    
    for rec_type, rec_link in item['rec_links'].items():
        persona = rec_type.split('_')[0]
        rec_id = None
        rec_category = None
        rec_author = None
        rec_type = rec_type.replace("control_society_rec", 'control_rec')
        
        if rec_link:
            rec_id = rec_link.split('/')[-1].split('?')[0]
        
        try:
            rec_category = link_to_category_dict[int(rec_id)]
            rec_author = link_to_author_dict[int(rec_id)]
        except:
            pass
        
        rows.append({
                    'distributed_link_id': dst_id,
                    'distributed_link_author': dstr_author,
                    'distributed_link_category': dstr_category,
                    'persona_category': persona,
                    'rec_category': rec_category,
                    'rec_author': rec_author
                })


df_categorized_temp = pd.DataFrame(rows)

# %%
df_categorized = df_categorized_temp.groupby(
    ['distributed_link_id', 'persona_category']
).agg({
    'distributed_link_category':'first',
    'distributed_link_author':'first',
    'rec_category': list,  # List all categories
    'rec_author': list,
}).reset_index()

# %%
df_categorized
# Out:
#      distributed_link_id persona_category distributed_link_category  \
# 0    7238391829421395243           beauty                    sports
# 1    7238391829421395243          control                    sports
# 2    7238391829421395243          society                    sports
# 3    7238391829421395243           sports                    sports
# 4    7287664074081586438           beauty                    sports
# ..                   ...              ...                       ...
# 395  7357026311220612394           sports                   society
# 396  7358538332013366570           beauty                   society
# 397  7358538332013366570          control                   society
# 398  7358538332013366570          society                   society
# 399  7358538332013366570           sports                   society
#
#       distributed_link_author  \
# 0             leah.givestipss
# 1             leah.givestipss
# 2             leah.givestipss
# 3             leah.givestipss
# 4                   taylerfit
# ..                        ...
# 395  the_inconvenient_truth88
# 396                     msnbc
# 397                     msnbc
# 398                     msnbc
# 399                     msnbc
#
#                                           rec_category  \
# 0    [other, None, None, None, None, None, None, None]
# 1    [sports, None, beauty, sports, other, beauty, ...
# 2    [other, other, other, society, other, other, o...
# 3    [other, other, other, None, None, other, other...
# 4    [sports, sports, sports, beauty, sports, sport...
# ..                                                 ...
# 395  [sports, beauty, other, sports, other, sports,...
# 396  [other, other, other, other, other, other, oth...
# 397  [other, sports, sports, other, None, other, ot...
# 398  [other, society, None, other, other, society, ...
# 399  [beauty, other, beauty, None, other, other, ot...
#
#                                             rec_author
# 0    [rileyscallon, None, None, None, None, None, N...
# 1    [denizms3_, None, good.creation, snookerchamp1...
# 2    [johayn.jumma, millenaeli, manu.gutierre8, cbs...
# 3    [iamnzae, nonbeatsz, icafabria, None, None, ka...
# 4    [taylerfit, taylerfit, taylerfit, packjower, t...
# ..                                                 ...
# 395  [notgracefuger, kxks.official, girlonset, ibra...
# 396  [donmahluvinlandrygame, uespiiiii.1115, megaam...
# 397  [steves.adventure, kazetskaya_mishka14, darkha...
# 398  [mebye.15, sbsnews_au, None, filssawadog, quee...
# 399  [iampipi.whoareyou, cloverwonyy, gudinhanches1...
#
# [400 rows x 6 columns]

# %%
from collections import Counter

def analysis(row,target):
    """basic analysis of our data"""
    target_category = row[target]
    category_counts = Counter(row['rec_category'])
    highest_count = max(category_counts.values())
    top_categories = [category for category, count in category_counts.items() if count == highest_count]

    isTopCount = target_category in top_categories
    num_rec_author = sum(1 for rec in row['rec_author'] if rec != None)
    num_rec_category = sum(1 for rec in row['rec_category'] if rec != None)
    propCategory = 0
    propSameAuthor = 0
    if target_category != None:
            if num_rec_category:
                propCategory = (category_counts[target_category] / num_rec_category)
            if num_rec_author:
                propSameAuthor = Counter(row['rec_author'])[row['distributed_link_author']] / num_rec_author

    isMajorityCount = propCategory > 0.5
    isFirst3Position = target_category in row['rec_category'][:3]
    isFirstPosition = target_category == row['rec_category'][0]
    
    return isTopCount, propCategory, isMajorityCount,isFirst3Position, isFirstPosition, propSameAuthor

df_categorized[['isTopCount_persona','prop_persona', 'isMajorityCount_persona', 'isFirst3Position_persona', 'isFirstPosition_persona', 'propSameAuthor']] = df_categorized.apply(lambda row: analysis(row, 'persona_category'), axis=1, result_type='expand')
df_categorized[['isTopCount_dst','prop_dst', 'isMajorityCount_dst', 'isFirst3Position_dst', 'isFirstPosition_dst','propSameAuthor']] = df_categorized.apply(lambda row: analysis(row, 'distributed_link_category'), axis=1, result_type='expand')

# %%
df_categorized.to_csv('./cleaned.csv')

# %%
df_categorized
# Out:
#      distributed_link_id persona_category distributed_link_category  \
# 0    7238391829421395243           beauty                    sports
# 1    7238391829421395243          control                    sports
# 2    7238391829421395243          society                    sports
# 3    7238391829421395243           sports                    sports
# 4    7287664074081586438           beauty                    sports
# ..                   ...              ...                       ...
# 395  7357026311220612394           sports                   society
# 396  7358538332013366570           beauty                   society
# 397  7358538332013366570          control                   society
# 398  7358538332013366570          society                   society
# 399  7358538332013366570           sports                   society
#
#       distributed_link_author  \
# 0             leah.givestipss
# 1             leah.givestipss
# 2             leah.givestipss
# 3             leah.givestipss
# 4                   taylerfit
# ..                        ...
# 395  the_inconvenient_truth88
# 396                     msnbc
# 397                     msnbc
# 398                     msnbc
# 399                     msnbc
#
#                                           rec_category  \
# 0    [other, None, None, None, None, None, None, None]
# 1    [sports, None, beauty, sports, other, beauty, ...
# 2    [other, other, other, society, other, other, o...
# 3    [other, other, other, None, None, other, other...
# 4    [sports, sports, sports, beauty, sports, sport...
# ..                                                 ...
# 395  [sports, beauty, other, sports, other, sports,...
# 396  [other, other, other, other, other, other, oth...
# 397  [other, sports, sports, other, None, other, ot...
# 398  [other, society, None, other, other, society, ...
# 399  [beauty, other, beauty, None, other, other, ot...
#
#                                             rec_author  isTopCount_persona  \
# 0    [rileyscallon, None, None, None, None, None, N...               False
# 1    [denizms3_, None, good.creation, snookerchamp1...               False
# 2    [johayn.jumma, millenaeli, manu.gutierre8, cbs...               False
# 3    [iamnzae, nonbeatsz, icafabria, None, None, ka...               False
# 4    [taylerfit, taylerfit, taylerfit, packjower, t...               False
# ..                                                 ...                 ...
# 395  [notgracefuger, kxks.official, girlonset, ibra...                True
# 396  [donmahluvinlandrygame, uespiiiii.1115, megaam...               False
# 397  [steves.adventure, kazetskaya_mishka14, darkha...               False
# 398  [mebye.15, sbsnews_au, None, filssawadog, quee...               False
# 399  [iampipi.whoareyou, cloverwonyy, gudinhanches1...               False
#
#      prop_persona  isMajorityCount_persona  isFirst3Position_persona  \
# 0        0.000000                    False                     False
# 1        0.000000                    False                     False
# 2        0.125000                    False                     False
# 3        0.000000                    False                     False
# 4        0.125000                    False                     False
# ..            ...                      ...                       ...
# 395      0.571429                     True                      True
# 396      0.000000                    False                     False
# 397      0.000000                    False                     False
# 398      0.400000                    False                      True
# 399      0.000000                    False                     False
#
#      isFirstPosition_persona  propSameAuthor  isTopCount_dst  prop_dst  \
# 0                      False            0.00           False  0.000000
# 1                      False            0.00            True  0.571429
# 2                      False            0.00           False  0.000000
# 3                      False            0.00           False  0.000000
# 4                      False            0.75            True  0.625000
# ..                       ...             ...             ...       ...
# 395                     True            0.00           False  0.000000
# 396                    False            0.00           False  0.000000
# 397                    False            0.00           False  0.000000
# 398                    False            0.00           False  0.400000
# 399                    False            0.00           False  0.000000
#
#      isMajorityCount_dst  isFirst3Position_dst  isFirstPosition_dst
# 0                  False                 False                False
# 1                   True                  True                 True
# 2                  False                 False                False
# 3                  False                 False                False
# 4                   True                  True                 True
# ..                   ...                   ...                  ...
# 395                False                 False                False
# 396                False                 False                False
# 397                False                 False                False
# 398                False                  True                False
# 399                False                 False                False
#
# [400 rows x 17 columns]
